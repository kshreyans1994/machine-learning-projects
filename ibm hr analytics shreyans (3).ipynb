# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.utils import shuffle

# %%
pd.set_option('display.max_columns',37)

# %%
df=pd.read_csv('F:\data science\data sets\IBM_HR.csv')
# Out:
# C:\Users\HP\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3063: DtypeWarning: Columns (5,8,10) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df.head()
# Out:
#     Age              Attrition BusinessTravel  DailyRate Department  \
# 0  41.0  Voluntary Resignation  Travel_Rarely     1102.0      Sales
# 1  41.0  Voluntary Resignation  Travel_Rarely     1102.0      Sales
# 2  41.0  Voluntary Resignation  Travel_Rarely     1102.0      Sales
# 3  41.0  Voluntary Resignation  Travel_Rarely     1102.0      Sales
# 4  41.0  Voluntary Resignation  Travel_Rarely     1102.0      Sales
#
#   DistanceFromHome  Education EducationField EmployeeCount EmployeeNumber  \
# 0                1        2.0  Life Sciences             1              1
# 1                1        2.0  Life Sciences             1              1
# 2                1        2.0  Life Sciences             1              7
# 3                1        2.0  Life Sciences             1              8
# 4                1        2.0  Life Sciences             1              9
#
#   Application ID  EnvironmentSatisfaction  Gender HourlyRate  JobInvolvement  \
# ...

# %%
df=shuffle(df)

# %%
df.head()
# Out:
#         Age              Attrition     BusinessTravel  DailyRate  \
# 10462  27.0       Current employee      Travel_Rarely     1130.0
# 10235  27.0       Current employee  Travel_Frequently      294.0
# 20816  52.0       Current employee  Travel_Frequently      890.0
# 7221   28.0  Voluntary Resignation         Non-Travel     1366.0
# 7207   28.0  Voluntary Resignation      Travel_Rarely      890.0
#
#                    Department DistanceFromHome  Education EducationField  \
# 10462                   Sales                8        4.0      Marketing
# 10235  Research & Development               10        2.0  Life Sciences
# 20816  Research & Development               25        4.0        Medical
# 7221   Research & Development               24        2.0          Other
# 7207   Research & Development                2        4.0  Life Sciences
#
#       EmployeeCount EmployeeNumber Application ID  EnvironmentSatisfaction  \
# ...

# %%
df.tail()
# Out:
#         Age              Attrition     BusinessTravel  DailyRate  \
# 19822  40.0       Current employee      Travel_Rarely      302.0
# 14902  35.0       Current employee      Travel_Rarely      982.0
# 3267   39.0  Voluntary Resignation  Travel_Frequently      203.0
# 13746  46.0       Current employee      Travel_Rarely     1003.0
# 21004  42.0       Current employee      Travel_Rarely      932.0
#
#                    Department DistanceFromHome  Education EducationField  \
# 19822  Research & Development                6        3.0  Life Sciences
# 14902  Research & Development                1        4.0        Medical
# 3267   Research & Development                2        3.0  Life Sciences
# 13746  Research & Development                8        4.0        Medical
# 21004  Research & Development                1        2.0  Life Sciences
#
#       EmployeeCount EmployeeNumber Application ID  EnvironmentSatisfaction  \
# ...

# %%
df.describe()
# Out:
#                 Age     DailyRate     Education  EnvironmentSatisfaction  \
# count  23433.000000  23424.000000  23424.000000             23427.000000
# mean      36.936671    801.828765      2.910050                13.681777
# std        9.137432    403.206166      1.024931              1186.544372
# min       18.000000    102.000000      1.000000                 1.000000
# 25%       30.000000    465.000000      2.000000                 2.000000
# 50%       36.000000    802.000000      3.000000                 3.000000
# 75%       43.000000   1157.000000      4.000000                 4.000000
# max       60.000000   1499.000000      6.000000            129588.000000
#
#        JobInvolvement      JobLevel   MonthlyRate  NumCompaniesWorked  \
# count    23427.000000  23429.000000  23425.000000        23427.000000
# mean         2.733811      2.064023  14304.343821            3.887779
# std          0.836860      1.105421   7102.636293          155.332904
# ...

# %%
df.shape
# Out:
# (23436, 37)

# %%
df.describe(include='object')
# Out:
#                Attrition BusinessTravel              Department  \
# count              23423          23428                   23425
# unique                 2              3                       4
# top     Current employee  Travel_Rarely  Research & Development
# freq               19714          16620                   15286
#
#        DistanceFromHome EducationField EmployeeCount EmployeeNumber  \
# count             23427          23427         23431          23435
# unique               59              8             3          23366
# top                   1  Life Sciences             1              1
# freq               2416           9701         16378              7
#
#        Application ID Gender HourlyRate          JobRole JobSatisfaction  \
# count           23433  23426      23427            23427           23427
# unique          23419      4         73               11               5
# top            123458   Male         66  Sales Executive               4
# ...

# %%
df['Attrition'].value_counts()
# Out:
# Current employee         19714
# Voluntary Resignation     3709
# Name: Attrition, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 23436 entries, 10462 to 21004
# Data columns (total 37 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       23433 non-null  float64
#  1   Attrition                 23423 non-null  object
#  2   BusinessTravel            23428 non-null  object
#  3   DailyRate                 23424 non-null  float64
#  4   Department                23425 non-null  object
#  5   DistanceFromHome          23427 non-null  object
#  6   Education                 23424 non-null  float64
#  7   EducationField            23427 non-null  object
#  8   EmployeeCount             23431 non-null  object
#  9   EmployeeNumber            23435 non-null  object
#  10  Application ID            23433 non-null  object
#  11  EnvironmentSatisfaction   23427 non-null  float64
#  12  Gender                    23426 non-null  object
# ...

# %%
df.isnull().sum()
# Out:
# Age                          3
# Attrition                   13
# BusinessTravel               8
# DailyRate                   12
# Department                  11
# DistanceFromHome             9
# Education                   12
# EducationField               9
# EmployeeCount                5
# EmployeeNumber               1
# Application ID               3
# EnvironmentSatisfaction      9
# Gender                      10
# HourlyRate                   9
# JobInvolvement               9
# JobLevel                     7
# JobRole                      9
# JobSatisfaction              9
# MaritalStatus               11
# MonthlyIncome               13
# MonthlyRate                 11
# NumCompaniesWorked           9
# Over18                      10
# OverTime                    12
# PercentSalaryHike           14
# PerformanceRating           10
# RelationshipSatisfaction     8
# StandardHours               10
# StockOptionLevel             9
# TotalWorkingYears            8
# ...

# %%
df.isnull().sum()/23436*100
# Out:
# Age                         0.012801
# Attrition                   0.055470
# BusinessTravel              0.034136
# DailyRate                   0.051203
# Department                  0.046936
# DistanceFromHome            0.038402
# Education                   0.051203
# EducationField              0.038402
# EmployeeCount               0.021335
# EmployeeNumber              0.004267
# Application ID              0.012801
# EnvironmentSatisfaction     0.038402
# Gender                      0.042669
# HourlyRate                  0.038402
# JobInvolvement              0.038402
# JobLevel                    0.029869
# JobRole                     0.038402
# JobSatisfaction             0.038402
# MaritalStatus               0.046936
# MonthlyIncome               0.055470
# MonthlyRate                 0.046936
# NumCompaniesWorked          0.038402
# Over18                      0.042669
# OverTime                    0.051203
# PercentSalaryHike           0.059737
# ...

# %%
df=df.dropna()

# %%
df.isnull().sum()
# Out:
# Age                         0
# Attrition                   0
# BusinessTravel              0
# DailyRate                   0
# Department                  0
# DistanceFromHome            0
# Education                   0
# EducationField              0
# EmployeeCount               0
# EmployeeNumber              0
# Application ID              0
# EnvironmentSatisfaction     0
# Gender                      0
# HourlyRate                  0
# JobInvolvement              0
# JobLevel                    0
# JobRole                     0
# JobSatisfaction             0
# MaritalStatus               0
# MonthlyIncome               0
# MonthlyRate                 0
# NumCompaniesWorked          0
# Over18                      0
# OverTime                    0
# PercentSalaryHike           0
# PerformanceRating           0
# RelationshipSatisfaction    0
# StandardHours               0
# StockOptionLevel            0
# TotalWorkingYears           0
# TrainingTimesLastYear       0
# ...

# %%
df.skew()
# Out:
# Age                         0.409287
# DailyRate                  -0.005547
# DistanceFromHome            0.960233
# Education                  -0.285427
# EmployeeCount               0.000000
# EnvironmentSatisfaction    -0.319937
# HourlyRate                 -0.034528
# JobInvolvement             -0.502518
# JobLevel                    1.021763
# JobSatisfaction            -0.330857
# MonthlyIncome               1.367708
# MonthlyRate                 0.018537
# NumCompaniesWorked          1.024913
# PercentSalaryHike           0.818430
# PerformanceRating           1.904259
# RelationshipSatisfaction   -0.302019
# StandardHours               0.000000
# StockOptionLevel            0.963246
# TotalWorkingYears           1.113948
# TrainingTimesLastYear       0.553221
# WorkLifeBalance            -0.551921
# YearsAtCompany              1.755784
# YearsInCurrentRole          0.916174
# YearsSinceLastPromotion     1.988293
# YearsWithCurrManager        0.829754
# dtype: float64

# %%
df.drop_duplicates(keep='first',inplace=True)
df.shape
# Out:
# (23190, 37)

# %%
#identifying unique identifers and remove them

# %%
df1=df.drop(['EmployeeCount',"EmployeeNumber","Application ID","Over18","StandardHours"],axis=1)

# %%
df1.shape
# Out:
# (23190, 32)

# %%
df1.corr()
# Out:
#                                Age  DailyRate  Education  \
# Age                       1.000000   0.012778   0.209577
# DailyRate                 0.012778   1.000000  -0.019011
# Education                 0.209577  -0.019011   1.000000
# EnvironmentSatisfaction  -0.005118   0.005777  -0.028119
# JobInvolvement           -0.005552   0.010538   0.021088
# JobLevel                  0.249829  -0.020115   0.047645
# MonthlyRate               0.036192  -0.013757  -0.004689
# NumCompaniesWorked        0.035073   0.017166   0.029360
# PerformanceRating        -0.007806   0.010069  -0.006218
# RelationshipSatisfaction  0.015963  -0.008017  -0.022006
# StockOptionLevel          0.006576   0.012023   0.018450
# TotalWorkingYears         0.325684  -0.000218   0.071316
# TrainingTimesLastYear     0.000090  -0.025568  -0.005303
# WorkLifeBalance          -0.003373  -0.033629   0.007677
# YearsAtCompany            0.140571  -0.038988   0.027507
# ...

# %%
# Impact of Age on Attrition of employees
sns.catplot(x='Age',hue='Attrition',data=df1,kind='count',height=15)

# %%
df1.shape
# Out:
# (23190, 32)

# %%
df1.select_dtypes(include= 'object').columns
# Out:
# Index(['Attrition', 'BusinessTravel', 'Department', 'DistanceFromHome',
#        'EducationField', 'Gender', 'HourlyRate', 'JobRole', 'JobSatisfaction',
#        'MaritalStatus', 'MonthlyIncome', 'OverTime', 'PercentSalaryHike',
#        'Employee Source'],
#       dtype='object')

# %%
df.describe(include='object')
# Out:
#                Attrition BusinessTravel              Department  \
# count              23190          23190                   23190
# unique                 2              3                       3
# top     Current employee  Travel_Rarely  Research & Development
# freq               19527          16443                   15125
#
#        DistanceFromHome EducationField EmployeeCount EmployeeNumber  \
# count             23190          23190         23190          23190
# unique               58              7             2          23141
# top                   1  Life Sciences             1          23244
# freq               2380           9571         16227              6
#
#        Application ID Gender HourlyRate          JobRole JobSatisfaction  \
# count           23190  23190      23190            23190           23190
# unique          23190      2         71                9               4
# top            143451   Male         66  Sales Executive               4
# ...

# %%
df1["DistanceFromHome"]=df["DistanceFromHome"].astype('int')
df1["EmployeeCount"]=df["EmployeeCount"].astype('int')
#df1["EmployeeNumber"]=df["EmployeeNumber"].astype('int')
df1["HourlyRate"]=df["HourlyRate"].astype('int')
df1["JobSatisfaction"]=df["JobSatisfaction"].astype('int')
df1["MonthlyIncome"]=df["MonthlyIncome"].astype('int')
df1["PercentSalaryHike"]=df["PercentSalaryHike"].astype('int')

# %%
df.describe(include='object')
# Out:
#                Attrition BusinessTravel              Department  \
# count              23190          23190                   23190
# unique                 2              3                       3
# top     Current employee  Travel_Rarely  Research & Development
# freq               19527          16443                   15125
#
#        DistanceFromHome EducationField EmployeeCount EmployeeNumber  \
# count             23190          23190         23190          23190
# unique               58              7             2          23141
# top                   1  Life Sciences             1          23244
# freq               2380           9571         16227              6
#
#        Application ID Gender HourlyRate          JobRole JobSatisfaction  \
# count           23190  23190      23190            23190           23190
# unique          23190      2         71                9               4
# top            143451   Male         66  Sales Executive               4
# ...

# %%
df1['Attrition'].value_counts()
# Out:
# Current employee         19527
# Voluntary Resignation     3663
# Name: Attrition, dtype: int64

# %%
df1['HourlyRate'].value_counts()
# Out:
# 66    478
# 84    441
# 48    440
# 42    439
# 96    434
#      ...
# 69    235
# 68    220
# 53    218
# 38    206
# 34    189
# Name: HourlyRate, Length: 71, dtype: int64

# %%
df1['Gender'].value_counts()
# Out:
# Male      13907
# Female     9283
# Name: Gender, dtype: int64

# %%
df1['OverTime'].value_counts()
# Out:
# No     16626
# Yes     6564
# Name: OverTime, dtype: int64

# %%
df1['JobSatisfaction'].value_counts()
# Out:
# 4    7209
# 3    7019
# 1    4560
# 2    4402
# Name: JobSatisfaction, dtype: int64

# %%
df1['JobRole'].value_counts()
# Out:
# Sales Executive              5057
# Research Scientist           4592
# Laboratory Technician        4100
# Manufacturing Director       2361
# Healthcare Representative    2077
# Manager                      1585
# Sales Representative         1299
# Research Director            1281
# Human Resources               838
# Name: JobRole, dtype: int64

# %%
df1['BusinessTravel'].value_counts()
# Out:
# Travel_Rarely        16443
# Travel_Frequently     4376
# Non-Travel            2371
# Name: BusinessTravel, dtype: int64

# %%
#Now we do label encoding
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()

# %%
df1.shape
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 23190 entries, 10462 to 21004
# Data columns (total 33 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       23190 non-null  float64
#  1   Attrition                 23190 non-null  object
#  2   BusinessTravel            23190 non-null  object
#  3   DailyRate                 23190 non-null  float64
#  4   Department                23190 non-null  object
#  5   DistanceFromHome          23190 non-null  int32
#  6   Education                 23190 non-null  float64
#  7   EducationField            23190 non-null  object
#  8   EnvironmentSatisfaction   23190 non-null  float64
#  9   Gender                    23190 non-null  object
#  10  HourlyRate                23190 non-null  int32
#  11  JobInvolvement            23190 non-null  float64
#  12  JobLevel                  23190 non-null  float64
# ...

# %%
df1[df1.select_dtypes(include= "object").columns]= df1[df1.select_dtypes(include='object').columns].apply(le.fit_transform)

# %%
df1.shape
# Out:
# (23190, 33)

# %%
df1.head(5)
# Out:
#         Age  Attrition  BusinessTravel  DailyRate  Department  \
# 10462  27.0          0               2     1130.0           2
# 10235  27.0          0               1      294.0           1
# 20816  52.0          0               1      890.0           1
# 7221   28.0          1               0     1366.0           1
# 7207   28.0          1               2      890.0           1
#
#        DistanceFromHome  Education  EducationField  EnvironmentSatisfaction  \
# 10462                 8        4.0               2                      3.0
# 10235                10        2.0               1                      1.0
# 20816                25        4.0               3                      3.0
# 7221                 24        2.0               4                      2.0
# 7207                  2        4.0               1                      3.0
#
#        Gender  HourlyRate  JobInvolvement  JobLevel  JobRole  JobSatisfaction  \
# ...

# %%
#data split

# %%
df1_X=df1.drop('Attrition',axis=1)
df1_y=df1['Attrition']

# %%
df1_X
# Out:
#         Age  BusinessTravel  DailyRate  Department  DistanceFromHome  \
# 10462  27.0               2     1130.0           2                 8
# 10235  27.0               1      294.0           1                10
# 20816  52.0               1      890.0           1                25
# 7221   28.0               0     1366.0           1                24
# 7207   28.0               2      890.0           1                 2
# ...     ...             ...        ...         ...               ...
# 19822  40.0               2      302.0           1                 6
# 14902  35.0               2      982.0           1                 1
# 3267   39.0               1      203.0           1                 2
# 13746  46.0               2     1003.0           1                 8
# 21004  42.0               2      932.0           1                 1
#
#        Education  EducationField  EnvironmentSatisfaction  Gender  HourlyRate  \
# ...

# %%
df1_y
# Out:
# 10462    0
# 10235    0
# 20816    0
# 7221     1
# 7207     1
#         ..
# 19822    0
# 14902    0
# 3267     1
# 13746    0
# 21004    0
# Name: Attrition, Length: 23190, dtype: int32

# %%
#sampling
from sklearn.model_selection import train_test_split
df1_X_train, df1_X_test, df1_y_train, df1_y_test= train_test_split(df1_X ,df1_y, test_size= .20)

# %%
from sklearn.linear_model import LogisticRegression
LogReg=LogisticRegression()

# %%
LogReg.fit(df1_X_train,df1_y_train)
# Out:
# C:\Users\HP\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:764: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# LogisticRegression()

# %%
pred_value=LogReg.predict(df1_X_test)

# %%
pred_value
# Out:
# array([0, 0, 0, ..., 0, 0, 0])

# %%
from sklearn.metrics import confusion_matrix
tab1=confusion_matrix(pred_value,df1_y_test)
tab1
# Out:
# array([[3895,  741],
#        [   0,    2]], dtype=int64)

# %%
tab1.diagonal().sum()
tab1.sum()
accuracy=tab1.diagonal().sum() / tab1.sum()*100

# %%
accuracy
# Out:
# 84.02328589909443

# %%
df1["Attrition"].value_counts()
# Out:
# 0    19527
# 1     3663
# Name: Attrition, dtype: int64

# %%
#lets check weather target varibale is balanced or not

# %%
sns.countplot(df1['Attrition'])

# %%
#data is highly imbalanced

# %%
from imblearn.over_sampling import SMOTE
smote = SMOTE('auto')
# Out:
# C:\Users\HP\anaconda3\lib\site-packages\imblearn\utils\_validation.py:638: FutureWarning: Pass sampling_strategy=auto as keyword args. From version 0.9 passing these as positional arguments will result in an error
#   FutureWarning)

# %%
X_sm, y_sm = smote.fit_sample(df1_X_train,df1_y_train)
print(X_sm.shape, y_sm.shape)
# Out:
# (31264, 32) (31264,)

# %%
LogReg=LogisticRegression()
LogReg.fit(X_sm,y_sm)
# Out:
# C:\Users\HP\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:764: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# LogisticRegression()

# %%
pred_value=LogReg.predict(df1_X_test)

# %%
from sklearn.metrics import confusion_matrix
tab1=confusion_matrix(pred_value,df1_y_test)
tab1
# Out:
# array([[2367,  286],
#        [1528,  457]], dtype=int64)

# %%
tab1.diagonal().sum()
tab1.sum()
accuracy=tab1.diagonal().sum() / tab1.sum()*100

# %%
accuracy
# Out:
# 60.888313928417425

# %%
from sklearn.metrics import classification_report
print( classification_report(pred_value,df1_y_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.61      0.89      0.72      2653
#            1       0.62      0.23      0.34      1985
#
#     accuracy                           0.61      4638
#    macro avg       0.61      0.56      0.53      4638
# weighted avg       0.61      0.61      0.56      4638

# %%
from sklearn.metrics import roc_auc_score
from sklearn.metrics import roc_curve

# %%
auc = roc_auc_score(df1_y_test, pred_value)
auc
# Out:
# 0.6113881032555456

# %%
#ROC
fpr, tpr, thresholds = roc_curve(df1_y_test, pred_value)
plt.plot(fpr, tpr, color='orange', label='ROC')
plt.plot([0, 1], [0, 1], color='darkblue', linestyle='--',label='ROC curve (area = %0.2f)' % auc)
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC) Curve')
plt.legend()
plt.show()

# %%
from sklearn.metrics import f1_score

# %%
f1 = f1_score(df1_y_test,pred_value)
f1
# Out:
# 0.33504398826979476

# %%
#Decision Tree

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import confusion_matrix
dt = DecisionTreeClassifier(criterion = "entropy",max_depth= 4,class_weight = "balanced")

# %%
dt.fit(df1_X_train,df1_y_train)
pred_dt = dt.predict(df1_X_test)

tab_dt = confusion_matrix(pred_dt,df1_y_test)
tab_dt
# Out:
# array([[2439,  217],
#        [1456,  526]], dtype=int64)

# %%
Accuracy = tab_dt.diagonal().sum()/tab_dt.sum() *100
Accuracy
# Out:
# 63.928417421302285

# %%
dt.feature_importances_
# Out:
# array([0.34345339, 0.        , 0.08355918, 0.0426673 , 0.02601297,
#        0.        , 0.        , 0.        , 0.        , 0.        ,
#        0.04531496, 0.        , 0.03307832, 0.        , 0.        ,
#        0.        , 0.        , 0.        , 0.18889183, 0.        ,
#        0.        , 0.        , 0.13750937, 0.03100352, 0.        ,
#        0.        , 0.04370341, 0.        , 0.        , 0.        ,
#        0.02480574, 0.        ])

# %%
dt.feature_importances_.sum()
# Out:
# 0.9999999999999998

# %%
importance_score = pd.DataFrame({"Features":df1_X_train.columns, "Importance" :dt.feature_importances_})

# %%
importance_score.sort_values("Importance" , ascending = False)
# Out:
#                     Features  Importance
# 0                        Age    0.343453
# 18                  OverTime    0.188892
# 22          StockOptionLevel    0.137509
# 2                  DailyRate    0.083559
# 10            JobInvolvement    0.045315
# 26            YearsAtCompany    0.043703
# 3                 Department    0.042667
# 12                   JobRole    0.033078
# 23         TotalWorkingYears    0.031004
# 4           DistanceFromHome    0.026013
# 30           Employee Source    0.024806
# 29      YearsWithCurrManager    0.000000
# 28   YearsSinceLastPromotion    0.000000
# 27        YearsInCurrentRole    0.000000
# 19         PercentSalaryHike    0.000000
# 25           WorkLifeBalance    0.000000
# 24     TrainingTimesLastYear    0.000000
# 21  RelationshipSatisfaction    0.000000
# 20         PerformanceRating    0.000000
# 16               MonthlyRate    0.000000
# 17        NumCompaniesWorked    0.000000
# 1             BusinessTravel    0.000000
# ...

# %%
#random forest

# %%
from sklearn.ensemble import RandomForestClassifier
rf = RandomForestClassifier(n_estimators = 100)
from sklearn.metrics import confusion_matrix

# %%
rf.fit(df1_X_train , df1_y_train)
pred_rf = rf.predict(df1_X_test)

tab_rf = confusion_matrix(pred_rf, df1_y_test)
tab_rf
# Out:
# array([[3894,   17],
#        [   1,  726]], dtype=int64)

# %%
Accuracy = tab_rf.diagonal().sum()/tab_rf.sum() *100
Accuracy
# Out:
# 96.57179818887451

# %%
#knn

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
knn = KNeighborsClassifier()

knn.fit(df1_X_train,df1_y_train)
# Out:
# KNeighborsClassifier()

# %%
pred_knn = knn.predict(df1_X_test)

# %%
tab_knn = confusion_matrix(pred_knn, df1_y_test)
tab_knn
# Out:
# array([[3845,  109],
#        [  50,  634]], dtype=int64)

# %%
Accuracy = tab_knn.diagonal().sum()/tab_knn.sum() *100
Accuracy
# Out:
# 96.57179818887451

# %%
from sklearn.svm import SVC

# %%
svm = SVC()
svm.fit(df1_X_train,df1_y_train)
# Out:
# SVC()

# %%
svm.fit(df1_X_train,df1_y_train)
# Out:
# SVC()

# %%
pred_svm= svm.predict(df1_X_test)

# %%
tab_knn = confusion_matrix(pred_svm, df1_y_test)
tab_knn
# Out:
# array([[3895,  743],
#        [   0,    0]], dtype=int64)

# %%
#xgboost

# %%
import xgboost as xgb
from xgboost import XGBClassifier

# %%
model = XGBClassifier(objective='binary:logistic')
model.fit(df1_X_train, df1_y_train)
# Out:
# C:\Users\HP\anaconda3\lib\site-packages\xgboost\sklearn.py:888: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [21:56:30] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#               colsample_bynode=1, colsample_bytree=1, gamma=0, gpu_id=-1,
#               importance_type='gain', interaction_constraints='',
# ...

# %%
pred_model = model.predict(df1_X_test)

# %%
tab_model = confusion_matrix(pred_model, df1_y_test)
tab_model
# Out:
# array([[3894,   11],
#        [   1,  732]], dtype=int64)

# %%
Accuracy = tab_model.diagonal().sum()/tab_model.sum() *100
Accuracy
# Out:
# 99.74126778783958
